# %%
import warnings
warnings.filterwarnings("ignore",category =RuntimeWarning)

# %% [markdown]
# ### Master Thesis: EigenGARCH(2021)
# We consider the new multivariate Dynamic Conditional Eigenvalue GARCH model (λ-MGARCH) introduced in Hetland et al. (2022 JoE). We are interested in evaluating its ability to forecast conditional covariance matrices, relative to competing multivariate GARCH models for time- varying conditional covariance matrice

# %% [markdown]
# ### Initial Estimation

# %%
# Import Packages
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from scipy.special import gamma
from scipy.stats import stats
from matplotlib import pyplot as plt 
import statsmodels.api as sm
import statsmodels as sms
import yfinance as yf
from numpy.linalg import eig

import Eigen_GARCH as Eigen_GARCH

# %% [markdown]
# #### Import Data

# %%
# Use the exact same data as in R, for the DCC and GO-GARCH model
data = np.array(pd.read_csv("returns_R.csv")).T

# %% [markdown]
# #### Estimate

# %%
# Set up bounds and lambdas
covdata = np.cov(data,bias=True)
T = data.shape[1]
k = 3
eigenvalues, eigenvectors = eig(covdata)
lambdas_eig = eigenvalues
bnds = [(-np.pi/2, np.pi/2)]
bnds_eig = [(0, np.pi)]

for i in range(2*(k**2)+k+2):
    bnds_eig.append((0, 100))

# Initial values
arguments_eig = (np.asarray(data),lambdas_eig)
startingVals_eig = [np.random.uniform(0.01,0.2) for i in range(2*(k**2) + k + 3)]

# Estimation
estimation = minimize(Eigen_GARCH.eigenLikelihood , x0=startingVals_eig , 
                          args=arguments_eig , method="SLSQP", bounds=bnds_eig, 
                          options={"maxiter":100000, "ftol":10e-14})

# %%
# Save the estimated parameter values
phi1_eig, phi2_eig, phi3_eig, w1_eig, w2_eig, w3_eig , a11_eig , a12_eig , a13_eig, a21_eig , a22_eig, a23_eig, a31_eig , a32_eig, a33_eig , b11_eig , b12_eig, b13_eig , b21_eig , b22_eig, b23_eig, b31_eig , b32_eig, b33_eig = estimation.x

# Find the llh and information criteria for the Eigen GARCH
llh = - estimation.fun
AIC = 2 * 24 - 2 * (llh)
BIC = - 2 * llh + np.log(T) * 24

# Load into matrices
W_eig = np.array(([w1_eig], [w2_eig], [w3_eig]))
A_eig = np.array(([a11_eig, a12_eig, a13_eig],
                  [a21_eig, a22_eig, a23_eig],
                  [a31_eig, a32_eig, a33_eig]))
B_eig = np.array(([b11_eig, b12_eig, b13_eig],
                  [b21_eig, b22_eig, b23_eig],
                  [b31_eig, b32_eig, b33_eig]))
V_eig = np.array(([np.cos(phi1_eig), np.sin(phi1_eig),0], [-np.sin(phi1_eig), np.cos(phi1_eig),0 ], [0, 0,1 ])
                )@ np.array(([np.cos(phi2_eig), 0, np.sin(phi2_eig)], [0, 1,0 ], [-np.sin(phi2_eig), 0, np.cos(phi2_eig)])
                           )@ np.array(( [1, 0,0 ], [0,np.cos(phi3_eig), np.sin(phi3_eig)], [0,-np.sin(phi3_eig), np.cos(phi3_eig)]))

print(f'W: {W_eig}')
print(f'A: {A_eig}')
print(f'B: {B_eig}')
print(f'V: {V_eig}')
print(f'Log-likelihood: {llh}')
print(f'AIC: {AIC}')
print(f'BIC: {BIC}')
# Out:
# W: [[0.17330707]
#  [0.0213585 ]
#  [0.01619998]]
# A: [[0.15332979 0.06420212 0.0755745 ]
#  [0.         0.08608764 0.00436416]
#  [0.04837691 0.01666142 0.07701433]]
# B: [[0.21098589 0.         0.11442386]
#  [0.         0.87533255 0.        ]
#  [0.         0.         0.90426174]]
# V: [[ 0.598446    0.10407646  0.79437427]
#  [-0.79034937  0.23905205  0.56409395]
#  [-0.1311879  -0.96541297  0.22531651]]
# Log-likelihood: -12439.961294352639
# AIC: 24927.922588705278
# BIC: 25065.28808803995

# %%
# Residuals
residuals = Eigen_GARCH.eigenresiduals(estimation.x, np.asarray(data), lambdas_eig)

# %%
# Misspisification test
print(stats.jarque_bera(residuals[0]))
print(stats.jarque_bera(residuals[1]))
print(stats.jarque_bera(residuals[2]))

print(sm.stats.acorr_ljungbox(residuals[0], lags=[10], return_df=True))
print(sm.stats.acorr_ljungbox(residuals[1], lags=[10], return_df=True))
print(sm.stats.acorr_ljungbox(residuals[2], lags=[10], return_df=True))
# Out:
# Jarque_beraResult(statistic=566884.9433041513, pvalue=0.0)
# Jarque_beraResult(statistic=316902.5037089753, pvalue=0.0)
# Jarque_beraResult(statistic=836281.6168794846, pvalue=0.0)
#       lb_stat     lb_pvalue
# 10  58.942066  5.743206e-09
#        lb_stat     lb_pvalue
# 10  110.962445  3.412338e-19
#        lb_stat     lb_pvalue
# 10  107.442408  1.747752e-18

# %%
# Skewness
print(stats.skew(residuals[0], axis=0, bias=True))
print(stats.skew(residuals[1], axis=0, bias=True))
print(stats.skew(residuals[2], axis=0, bias=True))
# Out:
# 1.0415907372952826
# -0.7315360806874415
# -3.2297753044322923

# %%
# Kurtosis
print(stats.kurtosis(residuals[0], axis=0, bias=True))
print(stats.kurtosis(residuals[1], axis=0, bias=True))
print(stats.kurtosis(residuals[2], axis=0, bias=True))
# Out:
# 77.54363227059817
# 57.980232098121036
# 93.99581418762114

# %%
# Calculate the covariance matrices based on the estimated values
Xtilde = V_eig.transpose() @ data
lambdas = (np.ones((T,k))).transpose()
condVar_eig = np.zeros((T,k,k))

for t in range(1,T):
    lambdas[:,t:t+1] = W_eig + A_eig @ np.multiply(Xtilde[:,t-1:t],Xtilde[:,t-1:t]) + B_eig @ lambdas[:,t-1:t]
    condVar_eig[t] = V_eig @ np.diag(np.concatenate(lambdas[:,t:t+1],axis= None)) @ V_eig.transpose()

# Make a list for each of the covariance pairs
cov_JPM_MSFT = []
for t in range(0,T):
    cov_JPM_MSFT.append(condVar_eig[t][0][1])

cov_JPM_KO = []
for t in range(0,T):
    cov_JPM_KO.append(condVar_eig[t][0][2])

cov_KO_MSFT = []
for t in range(0,T):
    cov_KO_MSFT.append(condVar_eig[t][1][2])

# %%
plt.plot(cov_JPM_MSFT)

# %%
# Save results 
df = pd.DataFrame(cov_JPM_KO)
df.to_csv('cov_JPM_KO_eigen.csv') 

df = pd.DataFrame(cov_JPM_MSFT)
df.to_csv('cov_JPM_MSFT_eigen.csv') 

df = pd.DataFrame(cov_KO_MSFT)
df.to_csv('cov_KO_MSFT_eigen.csv')

# %% [markdown]
# ### Pre period

# %%
# Use the exact same data as in R, for the DCC and GO-GARCH model
data_pre = np.array(pd.read_csv("returns_R.csv")[0:1506]).T

# %%
# Set up bounds and lambdas
covdata = np.cov(data_pre,bias=True)
T = data_pre.shape[1]
k = 3
eigenvalues, eigenvectors = eig(covdata)
lambdas_eig = eigenvalues
bnds = [(-np.pi/2, np.pi/2)]
bnds_eig = [(0, np.pi)]

for i in range(2*(k**2)+k+2):
    bnds_eig.append((0, 100))

# Initial values
arguments_eig = (np.asarray(data_pre),lambdas_eig)
startingVals_eig = [np.random.uniform(0.01,0.2) for i in range(2*(k**2) + k + 3)]

# Estimation
estimation = minimize(Eigen_GARCH.eigenLikelihood , x0=startingVals_eig , 
                          args=arguments_eig , method="SLSQP", bounds=bnds_eig, 
                          options={"maxiter":100000, "ftol":10e-14})
# Out:
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:39: RuntimeWarning: overflow encountered in matmul
#   lambdas[:,t:t+1] = W + A @ np.multiply(Xtilde[:,t-1:t],Xtilde[:,t-1:t]) + B @ lambdas[:,t-1:t]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:44: RuntimeWarning: divide by zero encountered in log
#   lls3 = np.log(lambdas[2,:]) + np.multiply(Xtilde[2,:],Xtilde[2,:]) / lambdas[2,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:44: RuntimeWarning: divide by zero encountered in true_divide
#   lls3 = np.log(lambdas[2,:]) + np.multiply(Xtilde[2,:],Xtilde[2,:]) / lambdas[2,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:44: RuntimeWarning: invalid value encountered in add
#   lls3 = np.log(lambdas[2,:]) + np.multiply(Xtilde[2,:],Xtilde[2,:]) / lambdas[2,:]

# %%
# Save the estimated parameter values
phi1_eig, phi2_eig, phi3_eig, w1_eig, w2_eig, w3_eig , a11_eig , a12_eig , a13_eig, a21_eig , a22_eig, a23_eig, a31_eig , a32_eig, a33_eig , b11_eig , b12_eig, b13_eig , b21_eig , b22_eig, b23_eig, b31_eig , b32_eig, b33_eig = estimation.x

# Find the llh and information criteria for the Eigen GARCH
llh = - estimation.fun
AIC = 2 * 24 - 2 * (llh)
BIC = - 2 * llh + np.log(T) * 24

# Load into matrices
W_eig = np.array(([w1_eig, w2_eig, w3_eig]))
A_eig = np.array(([a11_eig, a12_eig, a13_eig],[a21_eig, a22_eig, a23_eig],[a31_eig, a32_eig, a33_eig]))
B_eig = np.array(([b11_eig, b12_eig, b13_eig],[b21_eig, b22_eig, b23_eig],[b31_eig, b32_eig, b33_eig]))
V_eig = np.array(([np.cos(phi1_eig), np.sin(phi1_eig),0], [-np.sin(phi1_eig), np.cos(phi1_eig),0 ], [0, 0,1 ]))@ np.array(([np.cos(phi2_eig), 0, np.sin(phi2_eig)], [0, 1,0 ], [-np.sin(phi2_eig), 0, np.cos(phi2_eig)]))@ np.array(( [1, 0,0 ], [0,np.cos(phi3_eig), np.sin(phi3_eig)], [0,-np.sin(phi3_eig), np.cos(phi3_eig)]))

print(f'Log-likelihood: {llh}')
print(f'AIC: {AIC}')
print(f'BIC: {BIC}')
# Out:
# Log-likelihood: -7838.240824443832
# AIC: 15724.481648887664
# BIC: 15852.0947466883

# %% [markdown]
# ### Post period

# %%
# Use the exact same data as in R, for the DCC and GO-GARCH model
data_post = np.array(pd.read_csv("returns_R.csv")[1506:]).T

# %%
# Set up bounds and lambdas
covdata = np.cov(data_post,bias=True)
T = data_post.shape[1]
k = 3
eigenvalues, eigenvectors = eig(covdata)
lambdas_eig = eigenvalues
bnds = [(-np.pi/2, np.pi/2)]
bnds_eig = [(0, np.pi)]

for i in range(2*(k**2)+k+2):
    bnds_eig.append((0, 100))

# Initial values
arguments_eig = (np.asarray(data_post),lambdas_eig)
startingVals_eig = [np.random.uniform(0.01,0.2) for i in range(2*(k**2) + k + 3)]

# Estimation
estimation = minimize(Eigen_GARCH.eigenLikelihood , x0=startingVals_eig , 
                          args=arguments_eig , method="SLSQP", bounds=bnds_eig, 
                          options={"maxiter":100000, "ftol":10e-14})
# Out:
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:39: RuntimeWarning: invalid value encountered in matmul
#   lambdas[:,t:t+1] = W + A @ np.multiply(Xtilde[:,t-1:t],Xtilde[:,t-1:t]) + B @ lambdas[:,t-1:t]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:42: RuntimeWarning: divide by zero encountered in log
#   lls1 = np.log(lambdas[0,:]) + np.multiply(Xtilde[0,:],Xtilde[0,:]) / lambdas[0,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:42: RuntimeWarning: divide by zero encountered in true_divide
#   lls1 = np.log(lambdas[0,:]) + np.multiply(Xtilde[0,:],Xtilde[0,:]) / lambdas[0,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:42: RuntimeWarning: invalid value encountered in add
#   lls1 = np.log(lambdas[0,:]) + np.multiply(Xtilde[0,:],Xtilde[0,:]) / lambdas[0,:]

# %%
# Save the estimated parameter values
phi1_eig, phi2_eig, phi3_eig, w1_eig, w2_eig, w3_eig , a11_eig , a12_eig , a13_eig, a21_eig , a22_eig, a23_eig, a31_eig , a32_eig, a33_eig , b11_eig , b12_eig, b13_eig , b21_eig , b22_eig, b23_eig, b31_eig , b32_eig, b33_eig = estimation.x

# Find the llh and information criteria for the Eigen GARCH
llh = - estimation.fun
AIC = 2 * 24 - 2 * (llh)
BIC = - 2 * llh + np.log(T) * 24

# Load into matrices
W_eig = np.array(([w1_eig, w2_eig, w3_eig]))
A_eig = np.array(([a11_eig, a12_eig, a13_eig],[a21_eig, a22_eig, a23_eig],[a31_eig, a32_eig, a33_eig]))
B_eig = np.array(([b11_eig, b12_eig, b13_eig],[b21_eig, b22_eig, b23_eig],[b31_eig, b32_eig, b33_eig]))
V_eig = np.array(([np.cos(phi1_eig), np.sin(phi1_eig),0], [-np.sin(phi1_eig), np.cos(phi1_eig),0 ], [0, 0,1 ]))@ np.array(([np.cos(phi2_eig), 0, np.sin(phi2_eig)], [0, 1,0 ], [-np.sin(phi2_eig), 0, np.cos(phi2_eig)]))@ np.array(( [1, 0,0 ], [0,np.cos(phi3_eig), np.sin(phi3_eig)], [0,-np.sin(phi3_eig), np.cos(phi3_eig)]))

print(f'Log-likelihood: {llh}')
print(f'AIC: {AIC}')
print(f'BIC: {BIC}')
# Out:
# Log-likelihood: -4506.151534200957
# AIC: 9060.303068401914
# BIC: 9171.34429438389

# %% [markdown]
# ### Forecast

# %%
# Use the exact same data as in R, for the DCC and GO-GARCH model
data_forecast = data

# %%
# Number of loops in forecast
p = 3
N = 756
# Create parameter containers and covariance matrix container
phi1_eig = np.zeros((N,1))
phi2_eig = np.zeros((N,1))
phi3_eig = np.zeros((N,1))

w1_eig = np.zeros((N,1))
w2_eig = np.zeros((N,1))
w3_eig = np.zeros((N,1))

a11_eig = np.zeros((N,1))
a12_eig = np.zeros((N,1))
a13_eig = np.zeros((N,1))
a21_eig = np.zeros((N,1))
a22_eig = np.zeros((N,1))
a23_eig = np.zeros((N,1))
a31_eig = np.zeros((N,1))
a32_eig = np.zeros((N,1))
a33_eig = np.zeros((N,1))

b11_eig = np.zeros((N,1))
b12_eig = np.zeros((N,1))
b13_eig = np.zeros((N,1))
b21_eig = np.zeros((N,1))
b22_eig = np.zeros((N,1))
b23_eig = np.zeros((N,1))
b31_eig = np.zeros((N,1))
b32_eig = np.zeros((N,1))
b33_eig = np.zeros((N,1))

forecastMatrix_eig = np.zeros((N,p,p))

# %%
for n in range(N):
    # Move estimation window by 5
    X = data_forecast[:,n:1505+n]
    X_f = data_forecast[:,1505+n:1505+n+1]
    print(n, "out of", N, "in Eigen-GARCH forecasting")
    # Generate new lambdas for likelihood estimation
    lambdas_eig = np.tile(np.linalg.eig(np.cov(X.T, rowvar=False))[0], (T,1))
    
    # Use prior estimation results as starting values
    startingVals_eig = list(estimation.x)
    
    # Arguments
    arguments_eig = (np.asarray(X), lambdas_eig)
    
    # Estimation
    estimation = minimize(Eigen_GARCH.eigenLikelihood, x0=startingVals_eig , args=arguments_eig , method="SLSQP", bounds=bnds_eig, options={"maxiter":100000, "ftol":10e-24})
    
    # Save parameters
    phi1_eig[n], phi2_eig[n], phi3_eig[n], w1_eig[n], w2_eig[n], w3_eig[n] , a11_eig[n] , a12_eig[n] , a13_eig[n], a21_eig [n], a22_eig[n], a23_eig[n], a31_eig[n] , a32_eig[n], a33_eig[n] , b11_eig[n] , b12_eig[n], b13_eig[n] , b21_eig[n] , b22_eig[n], b23_eig[n], b31_eig[n] , b32_eig[n], b33_eig[n] = estimation.x
    phi1, phi2, phi3, w1, w2, w3, a11, a12, a13, a21, a22, a23, a31, a32, a33, b11, b12, b13, b21, b22,b23, b31, b32,b33 = estimation.x
 
    W_eig = np.array(([w1, w2, w3]))
    A_eig = np.array(([a11, a12,a13],
                  [a21, a22,a23],
                  [a31, a32,a33]))
    B_eig = np.array(([b11, b12,b13],
                  [b21, b22,b23],
                  [b31, b32,b33]))
    V_eig = np.array(([np.cos(phi1), np.sin(phi1),0],[-np.sin(phi1), np.cos(phi1),0 ], [0, 0,1 ])
                    )@ np.array(([np.cos(phi2), 0, np.sin(phi2)], [0, 1,0 ], [-np.sin(phi2), 0, np.cos(phi2)])
                           )@ np.array(( [1, 0,0 ], [0,np.cos(phi3), np.sin(phi3)], [0,-np.sin(phi3), np.cos(phi3)]))
    
    Xtilde = V_eig.transpose() @ X
    T = 1505
    lambdas = (np.ones((k,T))).transpose()
    
    condVar_eig = np.zeros((T,k,k))
    
    for t in range(1,T):
        lambdas[t] = W_eig+np.concatenate(A_eig @ np.multiply(Xtilde[:,t-1:t],Xtilde[:,t-1:t]), axis=0 )+ B_eig @ lambdas[t-1]
        condVar_eig[t] = V_eig @ np.diag(lambdas[t]) @ V_eig.T
     
    Xtilde_f = V_eig.transpose() @ X_f
    
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas[T-1]
 
    # Conditional eigenvalue at time t+1
    #Xtilde = V_eig.transpose() @ X
    
    # Store 1-step forecast
    #forecastMatrix_eig[n,:,:] = condVar_eig[T-1]
    forecastMatrix_eig[n,:,:] = V_eig @ np.diag(lambdas_f) @ V_eig.T
# Out:
# 0 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:43: RuntimeWarning: divide by zero encountered in log
#   lls2 = np.log(lambdas[1,:]) + np.multiply(Xtilde[1,:],Xtilde[1,:]) / lambdas[1,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:43: RuntimeWarning: divide by zero encountered in true_divide
#   lls2 = np.log(lambdas[1,:]) + np.multiply(Xtilde[1,:],Xtilde[1,:]) / lambdas[1,:]
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:43: RuntimeWarning: invalid value encountered in add
#   lls2 = np.log(lambdas[1,:]) + np.multiply(Xtilde[1,:],Xtilde[1,:]) / lambdas[1,:]
# 1 out of 756 in Eigen-GARCH forecasting
# 2 out of 756 in Eigen-GARCH forecasting
# 3 out of 756 in Eigen-GARCH forecasting
# 4 out of 756 in Eigen-GARCH forecasting
# 5 out of 756 in Eigen-GARCH forecasting
# 6 out of 756 in Eigen-GARCH forecasting
# 7 out of 756 in Eigen-GARCH forecasting
# 8 out of 756 in Eigen-GARCH forecasting
# 9 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:43: RuntimeWarning: overflow encountered in true_divide
#   lls2 = np.log(lambdas[1,:]) + np.multiply(Xtilde[1,:],Xtilde[1,:]) / lambdas[1,:]
# 10 out of 756 in Eigen-GARCH forecasting
# 11 out of 756 in Eigen-GARCH forecasting
# 12 out of 756 in Eigen-GARCH forecasting
# 13 out of 756 in Eigen-GARCH forecasting
# 14 out of 756 in Eigen-GARCH forecasting
# 15 out of 756 in Eigen-GARCH forecasting
# 16 out of 756 in Eigen-GARCH forecasting
# 17 out of 756 in Eigen-GARCH forecasting
# 18 out of 756 in Eigen-GARCH forecasting
# 19 out of 756 in Eigen-GARCH forecasting
# 20 out of 756 in Eigen-GARCH forecasting
# 21 out of 756 in Eigen-GARCH forecasting
# 22 out of 756 in Eigen-GARCH forecasting
# 23 out of 756 in Eigen-GARCH forecasting
# 24 out of 756 in Eigen-GARCH forecasting
# 25 out of 756 in Eigen-GARCH forecasting
# 26 out of 756 in Eigen-GARCH forecasting
# 27 out of 756 in Eigen-GARCH forecasting
# 28 out of 756 in Eigen-GARCH forecasting
# 29 out of 756 in Eigen-GARCH forecasting
# 30 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:42: RuntimeWarning: overflow encountered in true_divide
#   lls1 = np.log(lambdas[0,:]) + np.multiply(Xtilde[0,:],Xtilde[0,:]) / lambdas[0,:]
# 31 out of 756 in Eigen-GARCH forecasting
# 32 out of 756 in Eigen-GARCH forecasting
# 33 out of 756 in Eigen-GARCH forecasting
# 34 out of 756 in Eigen-GARCH forecasting
# 35 out of 756 in Eigen-GARCH forecasting
# 36 out of 756 in Eigen-GARCH forecasting
# 37 out of 756 in Eigen-GARCH forecasting
# 38 out of 756 in Eigen-GARCH forecasting
# 39 out of 756 in Eigen-GARCH forecasting
# 40 out of 756 in Eigen-GARCH forecasting
# 41 out of 756 in Eigen-GARCH forecasting
# 42 out of 756 in Eigen-GARCH forecasting
# 43 out of 756 in Eigen-GARCH forecasting
# 44 out of 756 in Eigen-GARCH forecasting
# 45 out of 756 in Eigen-GARCH forecasting
# 46 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:44: RuntimeWarning: overflow encountered in true_divide
#   lls3 = np.log(lambdas[2,:]) + np.multiply(Xtilde[2,:],Xtilde[2,:]) / lambdas[2,:]
# 47 out of 756 in Eigen-GARCH forecasting
# 48 out of 756 in Eigen-GARCH forecasting
# 49 out of 756 in Eigen-GARCH forecasting
# 50 out of 756 in Eigen-GARCH forecasting
# 51 out of 756 in Eigen-GARCH forecasting
# 52 out of 756 in Eigen-GARCH forecasting
# 53 out of 756 in Eigen-GARCH forecasting
# 54 out of 756 in Eigen-GARCH forecasting
# 55 out of 756 in Eigen-GARCH forecasting
# 56 out of 756 in Eigen-GARCH forecasting
# 57 out of 756 in Eigen-GARCH forecasting
# 58 out of 756 in Eigen-GARCH forecasting
# 59 out of 756 in Eigen-GARCH forecasting
# 60 out of 756 in Eigen-GARCH forecasting
# 61 out of 756 in Eigen-GARCH forecasting
# 62 out of 756 in Eigen-GARCH forecasting
# 63 out of 756 in Eigen-GARCH forecasting
# 64 out of 756 in Eigen-GARCH forecasting
# 65 out of 756 in Eigen-GARCH forecasting
# 66 out of 756 in Eigen-GARCH forecasting
# 67 out of 756 in Eigen-GARCH forecasting
# 68 out of 756 in Eigen-GARCH forecasting
# 69 out of 756 in Eigen-GARCH forecasting
# 70 out of 756 in Eigen-GARCH forecasting
# 71 out of 756 in Eigen-GARCH forecasting
# 72 out of 756 in Eigen-GARCH forecasting
# 73 out of 756 in Eigen-GARCH forecasting
# 74 out of 756 in Eigen-GARCH forecasting
# 75 out of 756 in Eigen-GARCH forecasting
# 76 out of 756 in Eigen-GARCH forecasting
# 77 out of 756 in Eigen-GARCH forecasting
# 78 out of 756 in Eigen-GARCH forecasting
# 79 out of 756 in Eigen-GARCH forecasting
# 80 out of 756 in Eigen-GARCH forecasting
# 81 out of 756 in Eigen-GARCH forecasting
# 82 out of 756 in Eigen-GARCH forecasting
# 83 out of 756 in Eigen-GARCH forecasting
# 84 out of 756 in Eigen-GARCH forecasting
# 85 out of 756 in Eigen-GARCH forecasting
# 86 out of 756 in Eigen-GARCH forecasting
# 87 out of 756 in Eigen-GARCH forecasting
# 88 out of 756 in Eigen-GARCH forecasting
# 89 out of 756 in Eigen-GARCH forecasting
# 90 out of 756 in Eigen-GARCH forecasting
# 91 out of 756 in Eigen-GARCH forecasting
# 92 out of 756 in Eigen-GARCH forecasting
# 93 out of 756 in Eigen-GARCH forecasting
# 94 out of 756 in Eigen-GARCH forecasting
# 95 out of 756 in Eigen-GARCH forecasting
# 96 out of 756 in Eigen-GARCH forecasting
# 97 out of 756 in Eigen-GARCH forecasting
# 98 out of 756 in Eigen-GARCH forecasting
# 99 out of 756 in Eigen-GARCH forecasting
# 100 out of 756 in Eigen-GARCH forecasting
# 101 out of 756 in Eigen-GARCH forecasting
# 102 out of 756 in Eigen-GARCH forecasting
# 103 out of 756 in Eigen-GARCH forecasting
# 104 out of 756 in Eigen-GARCH forecasting
# 105 out of 756 in Eigen-GARCH forecasting
# 106 out of 756 in Eigen-GARCH forecasting
# 107 out of 756 in Eigen-GARCH forecasting
# 108 out of 756 in Eigen-GARCH forecasting
# 109 out of 756 in Eigen-GARCH forecasting
# 110 out of 756 in Eigen-GARCH forecasting
# 111 out of 756 in Eigen-GARCH forecasting
# 112 out of 756 in Eigen-GARCH forecasting
# 113 out of 756 in Eigen-GARCH forecasting
# 114 out of 756 in Eigen-GARCH forecasting
# 115 out of 756 in Eigen-GARCH forecasting
# 116 out of 756 in Eigen-GARCH forecasting
# 117 out of 756 in Eigen-GARCH forecasting
# 118 out of 756 in Eigen-GARCH forecasting
# 119 out of 756 in Eigen-GARCH forecasting
# 120 out of 756 in Eigen-GARCH forecasting
# 121 out of 756 in Eigen-GARCH forecasting
# 122 out of 756 in Eigen-GARCH forecasting
# 123 out of 756 in Eigen-GARCH forecasting
# 124 out of 756 in Eigen-GARCH forecasting
# 125 out of 756 in Eigen-GARCH forecasting
# 126 out of 756 in Eigen-GARCH forecasting
# 127 out of 756 in Eigen-GARCH forecasting
# 128 out of 756 in Eigen-GARCH forecasting
# 129 out of 756 in Eigen-GARCH forecasting
# 130 out of 756 in Eigen-GARCH forecasting
# 131 out of 756 in Eigen-GARCH forecasting
# 132 out of 756 in Eigen-GARCH forecasting
# 133 out of 756 in Eigen-GARCH forecasting
# 134 out of 756 in Eigen-GARCH forecasting
# 135 out of 756 in Eigen-GARCH forecasting
# 136 out of 756 in Eigen-GARCH forecasting
# 137 out of 756 in Eigen-GARCH forecasting
# 138 out of 756 in Eigen-GARCH forecasting
# 139 out of 756 in Eigen-GARCH forecasting
# 140 out of 756 in Eigen-GARCH forecasting
# 141 out of 756 in Eigen-GARCH forecasting
# 142 out of 756 in Eigen-GARCH forecasting
# 143 out of 756 in Eigen-GARCH forecasting
# 144 out of 756 in Eigen-GARCH forecasting
# 145 out of 756 in Eigen-GARCH forecasting
# 146 out of 756 in Eigen-GARCH forecasting
# 147 out of 756 in Eigen-GARCH forecasting
# 148 out of 756 in Eigen-GARCH forecasting
# 149 out of 756 in Eigen-GARCH forecasting
# 150 out of 756 in Eigen-GARCH forecasting
# 151 out of 756 in Eigen-GARCH forecasting
# 152 out of 756 in Eigen-GARCH forecasting
# 153 out of 756 in Eigen-GARCH forecasting
# 154 out of 756 in Eigen-GARCH forecasting
# 155 out of 756 in Eigen-GARCH forecasting
# 156 out of 756 in Eigen-GARCH forecasting
# 157 out of 756 in Eigen-GARCH forecasting
# 158 out of 756 in Eigen-GARCH forecasting
# 159 out of 756 in Eigen-GARCH forecasting
# 160 out of 756 in Eigen-GARCH forecasting
# 161 out of 756 in Eigen-GARCH forecasting
# 162 out of 756 in Eigen-GARCH forecasting
# 163 out of 756 in Eigen-GARCH forecasting
# 164 out of 756 in Eigen-GARCH forecasting
# 165 out of 756 in Eigen-GARCH forecasting
# 166 out of 756 in Eigen-GARCH forecasting
# 167 out of 756 in Eigen-GARCH forecasting
# 168 out of 756 in Eigen-GARCH forecasting
# 169 out of 756 in Eigen-GARCH forecasting
# 170 out of 756 in Eigen-GARCH forecasting
# 171 out of 756 in Eigen-GARCH forecasting
# 172 out of 756 in Eigen-GARCH forecasting
# 173 out of 756 in Eigen-GARCH forecasting
# 174 out of 756 in Eigen-GARCH forecasting
# 175 out of 756 in Eigen-GARCH forecasting
# 176 out of 756 in Eigen-GARCH forecasting
# 177 out of 756 in Eigen-GARCH forecasting
# 178 out of 756 in Eigen-GARCH forecasting
# 179 out of 756 in Eigen-GARCH forecasting
# 180 out of 756 in Eigen-GARCH forecasting
# 181 out of 756 in Eigen-GARCH forecasting
# 182 out of 756 in Eigen-GARCH forecasting
# 183 out of 756 in Eigen-GARCH forecasting
# 184 out of 756 in Eigen-GARCH forecasting
# 185 out of 756 in Eigen-GARCH forecasting
# 186 out of 756 in Eigen-GARCH forecasting
# 187 out of 756 in Eigen-GARCH forecasting
# 188 out of 756 in Eigen-GARCH forecasting
# 189 out of 756 in Eigen-GARCH forecasting
# 190 out of 756 in Eigen-GARCH forecasting
# 191 out of 756 in Eigen-GARCH forecasting
# 192 out of 756 in Eigen-GARCH forecasting
# 193 out of 756 in Eigen-GARCH forecasting
# 194 out of 756 in Eigen-GARCH forecasting
# 195 out of 756 in Eigen-GARCH forecasting
# 196 out of 756 in Eigen-GARCH forecasting
# 197 out of 756 in Eigen-GARCH forecasting
# 198 out of 756 in Eigen-GARCH forecasting
# 199 out of 756 in Eigen-GARCH forecasting
# 200 out of 756 in Eigen-GARCH forecasting
# 201 out of 756 in Eigen-GARCH forecasting
# 202 out of 756 in Eigen-GARCH forecasting
# 203 out of 756 in Eigen-GARCH forecasting
# 204 out of 756 in Eigen-GARCH forecasting
# 205 out of 756 in Eigen-GARCH forecasting
# 206 out of 756 in Eigen-GARCH forecasting
# 207 out of 756 in Eigen-GARCH forecasting
# 208 out of 756 in Eigen-GARCH forecasting
# 209 out of 756 in Eigen-GARCH forecasting
# 210 out of 756 in Eigen-GARCH forecasting
# 211 out of 756 in Eigen-GARCH forecasting
# 212 out of 756 in Eigen-GARCH forecasting
# 213 out of 756 in Eigen-GARCH forecasting
# 214 out of 756 in Eigen-GARCH forecasting
# 215 out of 756 in Eigen-GARCH forecasting
# 216 out of 756 in Eigen-GARCH forecasting
# 217 out of 756 in Eigen-GARCH forecasting
# 218 out of 756 in Eigen-GARCH forecasting
# 219 out of 756 in Eigen-GARCH forecasting
# 220 out of 756 in Eigen-GARCH forecasting
# 221 out of 756 in Eigen-GARCH forecasting
# 222 out of 756 in Eigen-GARCH forecasting
# 223 out of 756 in Eigen-GARCH forecasting
# 224 out of 756 in Eigen-GARCH forecasting
# 225 out of 756 in Eigen-GARCH forecasting
# 226 out of 756 in Eigen-GARCH forecasting
# 227 out of 756 in Eigen-GARCH forecasting
# 228 out of 756 in Eigen-GARCH forecasting
# 229 out of 756 in Eigen-GARCH forecasting
# 230 out of 756 in Eigen-GARCH forecasting
# 231 out of 756 in Eigen-GARCH forecasting
# 232 out of 756 in Eigen-GARCH forecasting
# 233 out of 756 in Eigen-GARCH forecasting
# 234 out of 756 in Eigen-GARCH forecasting
# 235 out of 756 in Eigen-GARCH forecasting
# 236 out of 756 in Eigen-GARCH forecasting
# 237 out of 756 in Eigen-GARCH forecasting
# 238 out of 756 in Eigen-GARCH forecasting
# 239 out of 756 in Eigen-GARCH forecasting
# 240 out of 756 in Eigen-GARCH forecasting
# 241 out of 756 in Eigen-GARCH forecasting
# 242 out of 756 in Eigen-GARCH forecasting
# 243 out of 756 in Eigen-GARCH forecasting
# 244 out of 756 in Eigen-GARCH forecasting
# 245 out of 756 in Eigen-GARCH forecasting
# 246 out of 756 in Eigen-GARCH forecasting
# 247 out of 756 in Eigen-GARCH forecasting
# 248 out of 756 in Eigen-GARCH forecasting
# 249 out of 756 in Eigen-GARCH forecasting
# 250 out of 756 in Eigen-GARCH forecasting
# 251 out of 756 in Eigen-GARCH forecasting
# 252 out of 756 in Eigen-GARCH forecasting
# 253 out of 756 in Eigen-GARCH forecasting
# 254 out of 756 in Eigen-GARCH forecasting
# 255 out of 756 in Eigen-GARCH forecasting
# 256 out of 756 in Eigen-GARCH forecasting
# 257 out of 756 in Eigen-GARCH forecasting
# 258 out of 756 in Eigen-GARCH forecasting
# 259 out of 756 in Eigen-GARCH forecasting
# 260 out of 756 in Eigen-GARCH forecasting
# 261 out of 756 in Eigen-GARCH forecasting
# 262 out of 756 in Eigen-GARCH forecasting
# 263 out of 756 in Eigen-GARCH forecasting
# 264 out of 756 in Eigen-GARCH forecasting
# 265 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:45: RuntimeWarning: overflow encountered in multiply
#   lls = (lls1 + lls2 + lls3)*p*np.log(2*np.pi)
# 266 out of 756 in Eigen-GARCH forecasting
# 267 out of 756 in Eigen-GARCH forecasting
# 268 out of 756 in Eigen-GARCH forecasting
# 269 out of 756 in Eigen-GARCH forecasting
# 270 out of 756 in Eigen-GARCH forecasting
# 271 out of 756 in Eigen-GARCH forecasting
# 272 out of 756 in Eigen-GARCH forecasting
# 273 out of 756 in Eigen-GARCH forecasting
# 274 out of 756 in Eigen-GARCH forecasting
# 275 out of 756 in Eigen-GARCH forecasting
# 276 out of 756 in Eigen-GARCH forecasting
# 277 out of 756 in Eigen-GARCH forecasting
# 278 out of 756 in Eigen-GARCH forecasting
# 279 out of 756 in Eigen-GARCH forecasting
# 280 out of 756 in Eigen-GARCH forecasting
# 281 out of 756 in Eigen-GARCH forecasting
# 282 out of 756 in Eigen-GARCH forecasting
# 283 out of 756 in Eigen-GARCH forecasting
# 284 out of 756 in Eigen-GARCH forecasting
# 285 out of 756 in Eigen-GARCH forecasting
# 286 out of 756 in Eigen-GARCH forecasting
# 287 out of 756 in Eigen-GARCH forecasting
# 288 out of 756 in Eigen-GARCH forecasting
# 289 out of 756 in Eigen-GARCH forecasting
# 290 out of 756 in Eigen-GARCH forecasting
# 291 out of 756 in Eigen-GARCH forecasting
# 292 out of 756 in Eigen-GARCH forecasting
# 293 out of 756 in Eigen-GARCH forecasting
# 294 out of 756 in Eigen-GARCH forecasting
# 295 out of 756 in Eigen-GARCH forecasting
# 296 out of 756 in Eigen-GARCH forecasting
# 297 out of 756 in Eigen-GARCH forecasting
# 298 out of 756 in Eigen-GARCH forecasting
# 299 out of 756 in Eigen-GARCH forecasting
# 300 out of 756 in Eigen-GARCH forecasting
# 301 out of 756 in Eigen-GARCH forecasting
# 302 out of 756 in Eigen-GARCH forecasting
# 303 out of 756 in Eigen-GARCH forecasting
# 304 out of 756 in Eigen-GARCH forecasting
# 305 out of 756 in Eigen-GARCH forecasting
# 306 out of 756 in Eigen-GARCH forecasting
# 307 out of 756 in Eigen-GARCH forecasting
# 308 out of 756 in Eigen-GARCH forecasting
# 309 out of 756 in Eigen-GARCH forecasting
# 310 out of 756 in Eigen-GARCH forecasting
# 311 out of 756 in Eigen-GARCH forecasting
# 312 out of 756 in Eigen-GARCH forecasting
# 313 out of 756 in Eigen-GARCH forecasting
# 314 out of 756 in Eigen-GARCH forecasting
# 315 out of 756 in Eigen-GARCH forecasting
# 316 out of 756 in Eigen-GARCH forecasting
# 317 out of 756 in Eigen-GARCH forecasting
# 318 out of 756 in Eigen-GARCH forecasting
# 319 out of 756 in Eigen-GARCH forecasting
# 320 out of 756 in Eigen-GARCH forecasting
# 321 out of 756 in Eigen-GARCH forecasting
# 322 out of 756 in Eigen-GARCH forecasting
# 323 out of 756 in Eigen-GARCH forecasting
# 324 out of 756 in Eigen-GARCH forecasting
# 325 out of 756 in Eigen-GARCH forecasting
# 326 out of 756 in Eigen-GARCH forecasting
# 327 out of 756 in Eigen-GARCH forecasting
# 328 out of 756 in Eigen-GARCH forecasting
# 329 out of 756 in Eigen-GARCH forecasting
# 330 out of 756 in Eigen-GARCH forecasting
# 331 out of 756 in Eigen-GARCH forecasting
# 332 out of 756 in Eigen-GARCH forecasting
# 333 out of 756 in Eigen-GARCH forecasting
# 334 out of 756 in Eigen-GARCH forecasting
# 335 out of 756 in Eigen-GARCH forecasting
# 336 out of 756 in Eigen-GARCH forecasting
# 337 out of 756 in Eigen-GARCH forecasting
# 338 out of 756 in Eigen-GARCH forecasting
# 339 out of 756 in Eigen-GARCH forecasting
# 340 out of 756 in Eigen-GARCH forecasting
# 341 out of 756 in Eigen-GARCH forecasting
# 342 out of 756 in Eigen-GARCH forecasting
# 343 out of 756 in Eigen-GARCH forecasting
# 344 out of 756 in Eigen-GARCH forecasting
# 345 out of 756 in Eigen-GARCH forecasting
# 346 out of 756 in Eigen-GARCH forecasting
# 347 out of 756 in Eigen-GARCH forecasting
# 348 out of 756 in Eigen-GARCH forecasting
# 349 out of 756 in Eigen-GARCH forecasting
# 350 out of 756 in Eigen-GARCH forecasting
# 351 out of 756 in Eigen-GARCH forecasting
# 352 out of 756 in Eigen-GARCH forecasting
# 353 out of 756 in Eigen-GARCH forecasting
# 354 out of 756 in Eigen-GARCH forecasting
# 355 out of 756 in Eigen-GARCH forecasting
# 356 out of 756 in Eigen-GARCH forecasting
# 357 out of 756 in Eigen-GARCH forecasting
# 358 out of 756 in Eigen-GARCH forecasting
# 359 out of 756 in Eigen-GARCH forecasting
# 360 out of 756 in Eigen-GARCH forecasting
# 361 out of 756 in Eigen-GARCH forecasting
# 362 out of 756 in Eigen-GARCH forecasting
# 363 out of 756 in Eigen-GARCH forecasting
# 364 out of 756 in Eigen-GARCH forecasting
# 365 out of 756 in Eigen-GARCH forecasting
# 366 out of 756 in Eigen-GARCH forecasting
# 367 out of 756 in Eigen-GARCH forecasting
# 368 out of 756 in Eigen-GARCH forecasting
# 369 out of 756 in Eigen-GARCH forecasting
# 370 out of 756 in Eigen-GARCH forecasting
# 371 out of 756 in Eigen-GARCH forecasting
# 372 out of 756 in Eigen-GARCH forecasting
# 373 out of 756 in Eigen-GARCH forecasting
# 374 out of 756 in Eigen-GARCH forecasting
# 375 out of 756 in Eigen-GARCH forecasting
# 376 out of 756 in Eigen-GARCH forecasting
# 377 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:42: RuntimeWarning: invalid value encountered in true_divide
#   lls1 = np.log(lambdas[0,:]) + np.multiply(Xtilde[0,:],Xtilde[0,:]) / lambdas[0,:]
# 378 out of 756 in Eigen-GARCH forecasting
# 379 out of 756 in Eigen-GARCH forecasting
# 380 out of 756 in Eigen-GARCH forecasting
# 381 out of 756 in Eigen-GARCH forecasting
# 382 out of 756 in Eigen-GARCH forecasting
# 383 out of 756 in Eigen-GARCH forecasting
# 384 out of 756 in Eigen-GARCH forecasting
# 385 out of 756 in Eigen-GARCH forecasting
# 386 out of 756 in Eigen-GARCH forecasting
# 387 out of 756 in Eigen-GARCH forecasting
# 388 out of 756 in Eigen-GARCH forecasting
# 389 out of 756 in Eigen-GARCH forecasting
# 390 out of 756 in Eigen-GARCH forecasting
# 391 out of 756 in Eigen-GARCH forecasting
# 392 out of 756 in Eigen-GARCH forecasting
# 393 out of 756 in Eigen-GARCH forecasting
# 394 out of 756 in Eigen-GARCH forecasting
# 395 out of 756 in Eigen-GARCH forecasting
# 396 out of 756 in Eigen-GARCH forecasting
# 397 out of 756 in Eigen-GARCH forecasting
# 398 out of 756 in Eigen-GARCH forecasting
# 399 out of 756 in Eigen-GARCH forecasting
# 400 out of 756 in Eigen-GARCH forecasting
# 401 out of 756 in Eigen-GARCH forecasting
# 402 out of 756 in Eigen-GARCH forecasting
# 403 out of 756 in Eigen-GARCH forecasting
# 404 out of 756 in Eigen-GARCH forecasting
# 405 out of 756 in Eigen-GARCH forecasting
# 406 out of 756 in Eigen-GARCH forecasting
# 407 out of 756 in Eigen-GARCH forecasting
# 408 out of 756 in Eigen-GARCH forecasting
# 409 out of 756 in Eigen-GARCH forecasting
# 410 out of 756 in Eigen-GARCH forecasting
# 411 out of 756 in Eigen-GARCH forecasting
# 412 out of 756 in Eigen-GARCH forecasting
# 413 out of 756 in Eigen-GARCH forecasting
# 414 out of 756 in Eigen-GARCH forecasting
# 415 out of 756 in Eigen-GARCH forecasting
# 416 out of 756 in Eigen-GARCH forecasting
# 417 out of 756 in Eigen-GARCH forecasting
# 418 out of 756 in Eigen-GARCH forecasting
# 419 out of 756 in Eigen-GARCH forecasting
# 420 out of 756 in Eigen-GARCH forecasting
# 421 out of 756 in Eigen-GARCH forecasting
# 422 out of 756 in Eigen-GARCH forecasting
# 423 out of 756 in Eigen-GARCH forecasting
# 424 out of 756 in Eigen-GARCH forecasting
# 425 out of 756 in Eigen-GARCH forecasting
# 426 out of 756 in Eigen-GARCH forecasting
# 427 out of 756 in Eigen-GARCH forecasting
# 428 out of 756 in Eigen-GARCH forecasting
# 429 out of 756 in Eigen-GARCH forecasting
# 430 out of 756 in Eigen-GARCH forecasting
# 431 out of 756 in Eigen-GARCH forecasting
# 432 out of 756 in Eigen-GARCH forecasting
# 433 out of 756 in Eigen-GARCH forecasting
# 434 out of 756 in Eigen-GARCH forecasting
# 435 out of 756 in Eigen-GARCH forecasting
# 436 out of 756 in Eigen-GARCH forecasting
# 437 out of 756 in Eigen-GARCH forecasting
# 438 out of 756 in Eigen-GARCH forecasting
# 439 out of 756 in Eigen-GARCH forecasting
# 440 out of 756 in Eigen-GARCH forecasting
# 441 out of 756 in Eigen-GARCH forecasting
# 442 out of 756 in Eigen-GARCH forecasting
# 443 out of 756 in Eigen-GARCH forecasting
# 444 out of 756 in Eigen-GARCH forecasting
# 445 out of 756 in Eigen-GARCH forecasting
# 446 out of 756 in Eigen-GARCH forecasting
# 447 out of 756 in Eigen-GARCH forecasting
# 448 out of 756 in Eigen-GARCH forecasting
# 449 out of 756 in Eigen-GARCH forecasting
# 450 out of 756 in Eigen-GARCH forecasting
# 451 out of 756 in Eigen-GARCH forecasting
# 452 out of 756 in Eigen-GARCH forecasting
# 453 out of 756 in Eigen-GARCH forecasting
# 454 out of 756 in Eigen-GARCH forecasting
# 455 out of 756 in Eigen-GARCH forecasting
# 456 out of 756 in Eigen-GARCH forecasting
# 457 out of 756 in Eigen-GARCH forecasting
# 458 out of 756 in Eigen-GARCH forecasting
# 459 out of 756 in Eigen-GARCH forecasting
# 460 out of 756 in Eigen-GARCH forecasting
# 461 out of 756 in Eigen-GARCH forecasting
# 462 out of 756 in Eigen-GARCH forecasting
# 463 out of 756 in Eigen-GARCH forecasting
# 464 out of 756 in Eigen-GARCH forecasting
# 465 out of 756 in Eigen-GARCH forecasting
# 466 out of 756 in Eigen-GARCH forecasting
# 467 out of 756 in Eigen-GARCH forecasting
# 468 out of 756 in Eigen-GARCH forecasting
# 469 out of 756 in Eigen-GARCH forecasting
# 470 out of 756 in Eigen-GARCH forecasting
# 471 out of 756 in Eigen-GARCH forecasting
# 472 out of 756 in Eigen-GARCH forecasting
# 473 out of 756 in Eigen-GARCH forecasting
# 474 out of 756 in Eigen-GARCH forecasting
# 475 out of 756 in Eigen-GARCH forecasting
# 476 out of 756 in Eigen-GARCH forecasting
# 477 out of 756 in Eigen-GARCH forecasting
# 478 out of 756 in Eigen-GARCH forecasting
# 479 out of 756 in Eigen-GARCH forecasting
# 480 out of 756 in Eigen-GARCH forecasting
# 481 out of 756 in Eigen-GARCH forecasting
# 482 out of 756 in Eigen-GARCH forecasting
# 483 out of 756 in Eigen-GARCH forecasting
# 484 out of 756 in Eigen-GARCH forecasting
# 485 out of 756 in Eigen-GARCH forecasting
# 486 out of 756 in Eigen-GARCH forecasting
# 487 out of 756 in Eigen-GARCH forecasting
# 488 out of 756 in Eigen-GARCH forecasting
# 489 out of 756 in Eigen-GARCH forecasting
# 490 out of 756 in Eigen-GARCH forecasting
# 491 out of 756 in Eigen-GARCH forecasting
# 492 out of 756 in Eigen-GARCH forecasting
# 493 out of 756 in Eigen-GARCH forecasting
# 494 out of 756 in Eigen-GARCH forecasting
# /Users/silkesommerfugl/Desktop/Master/Eigen_GARCH.py:44: RuntimeWarning: invalid value encountered in true_divide
#   lls3 = np.log(lambdas[2,:]) + np.multiply(Xtilde[2,:],Xtilde[2,:]) / lambdas[2,:]
# 495 out of 756 in Eigen-GARCH forecasting
# 496 out of 756 in Eigen-GARCH forecasting
# 497 out of 756 in Eigen-GARCH forecasting
# 498 out of 756 in Eigen-GARCH forecasting
# 499 out of 756 in Eigen-GARCH forecasting
# 500 out of 756 in Eigen-GARCH forecasting
# 501 out of 756 in Eigen-GARCH forecasting
# 502 out of 756 in Eigen-GARCH forecasting
# 503 out of 756 in Eigen-GARCH forecasting
# 504 out of 756 in Eigen-GARCH forecasting
# 505 out of 756 in Eigen-GARCH forecasting
# 506 out of 756 in Eigen-GARCH forecasting
# 507 out of 756 in Eigen-GARCH forecasting
# 508 out of 756 in Eigen-GARCH forecasting
# 509 out of 756 in Eigen-GARCH forecasting
# 510 out of 756 in Eigen-GARCH forecasting
# 511 out of 756 in Eigen-GARCH forecasting
# 512 out of 756 in Eigen-GARCH forecasting
# 513 out of 756 in Eigen-GARCH forecasting
# 514 out of 756 in Eigen-GARCH forecasting
# 515 out of 756 in Eigen-GARCH forecasting
# 516 out of 756 in Eigen-GARCH forecasting
# 517 out of 756 in Eigen-GARCH forecasting
# 518 out of 756 in Eigen-GARCH forecasting
# 519 out of 756 in Eigen-GARCH forecasting
# 520 out of 756 in Eigen-GARCH forecasting
# 521 out of 756 in Eigen-GARCH forecasting
# 522 out of 756 in Eigen-GARCH forecasting
# 523 out of 756 in Eigen-GARCH forecasting
# 524 out of 756 in Eigen-GARCH forecasting
# 525 out of 756 in Eigen-GARCH forecasting
# 526 out of 756 in Eigen-GARCH forecasting
# 527 out of 756 in Eigen-GARCH forecasting
# 528 out of 756 in Eigen-GARCH forecasting
# 529 out of 756 in Eigen-GARCH forecasting
# 530 out of 756 in Eigen-GARCH forecasting
# 531 out of 756 in Eigen-GARCH forecasting
# 532 out of 756 in Eigen-GARCH forecasting
# 533 out of 756 in Eigen-GARCH forecasting
# 534 out of 756 in Eigen-GARCH forecasting
# 535 out of 756 in Eigen-GARCH forecasting
# 536 out of 756 in Eigen-GARCH forecasting
# 537 out of 756 in Eigen-GARCH forecasting
# 538 out of 756 in Eigen-GARCH forecasting
# 539 out of 756 in Eigen-GARCH forecasting
# 540 out of 756 in Eigen-GARCH forecasting
# 541 out of 756 in Eigen-GARCH forecasting
# 542 out of 756 in Eigen-GARCH forecasting
# 543 out of 756 in Eigen-GARCH forecasting
# 544 out of 756 in Eigen-GARCH forecasting
# 545 out of 756 in Eigen-GARCH forecasting
# 546 out of 756 in Eigen-GARCH forecasting
# 547 out of 756 in Eigen-GARCH forecasting
# 548 out of 756 in Eigen-GARCH forecasting
# 549 out of 756 in Eigen-GARCH forecasting
# 550 out of 756 in Eigen-GARCH forecasting
# 551 out of 756 in Eigen-GARCH forecasting
# 552 out of 756 in Eigen-GARCH forecasting
# 553 out of 756 in Eigen-GARCH forecasting
# 554 out of 756 in Eigen-GARCH forecasting
# 555 out of 756 in Eigen-GARCH forecasting
# 556 out of 756 in Eigen-GARCH forecasting
# 557 out of 756 in Eigen-GARCH forecasting
# 558 out of 756 in Eigen-GARCH forecasting
# 559 out of 756 in Eigen-GARCH forecasting
# 560 out of 756 in Eigen-GARCH forecasting
# 561 out of 756 in Eigen-GARCH forecasting
# 562 out of 756 in Eigen-GARCH forecasting
# 563 out of 756 in Eigen-GARCH forecasting
# 564 out of 756 in Eigen-GARCH forecasting
# 565 out of 756 in Eigen-GARCH forecasting
# 566 out of 756 in Eigen-GARCH forecasting
# 567 out of 756 in Eigen-GARCH forecasting
# 568 out of 756 in Eigen-GARCH forecasting
# 569 out of 756 in Eigen-GARCH forecasting
# 570 out of 756 in Eigen-GARCH forecasting
# 571 out of 756 in Eigen-GARCH forecasting
# 572 out of 756 in Eigen-GARCH forecasting
# 573 out of 756 in Eigen-GARCH forecasting
# 574 out of 756 in Eigen-GARCH forecasting
# 575 out of 756 in Eigen-GARCH forecasting
# 576 out of 756 in Eigen-GARCH forecasting
# 577 out of 756 in Eigen-GARCH forecasting
# 578 out of 756 in Eigen-GARCH forecasting
# 579 out of 756 in Eigen-GARCH forecasting
# 580 out of 756 in Eigen-GARCH forecasting
# 581 out of 756 in Eigen-GARCH forecasting
# 582 out of 756 in Eigen-GARCH forecasting
# 583 out of 756 in Eigen-GARCH forecasting
# 584 out of 756 in Eigen-GARCH forecasting
# 585 out of 756 in Eigen-GARCH forecasting
# 586 out of 756 in Eigen-GARCH forecasting
# 587 out of 756 in Eigen-GARCH forecasting
# 588 out of 756 in Eigen-GARCH forecasting
# 589 out of 756 in Eigen-GARCH forecasting
# 590 out of 756 in Eigen-GARCH forecasting
# 591 out of 756 in Eigen-GARCH forecasting
# 592 out of 756 in Eigen-GARCH forecasting
# 593 out of 756 in Eigen-GARCH forecasting
# 594 out of 756 in Eigen-GARCH forecasting
# 595 out of 756 in Eigen-GARCH forecasting
# 596 out of 756 in Eigen-GARCH forecasting
# 597 out of 756 in Eigen-GARCH forecasting
# 598 out of 756 in Eigen-GARCH forecasting
# 599 out of 756 in Eigen-GARCH forecasting
# 600 out of 756 in Eigen-GARCH forecasting
# 601 out of 756 in Eigen-GARCH forecasting
# 602 out of 756 in Eigen-GARCH forecasting
# 603 out of 756 in Eigen-GARCH forecasting
# 604 out of 756 in Eigen-GARCH forecasting
# 605 out of 756 in Eigen-GARCH forecasting
# 606 out of 756 in Eigen-GARCH forecasting
# 607 out of 756 in Eigen-GARCH forecasting
# 608 out of 756 in Eigen-GARCH forecasting
# 609 out of 756 in Eigen-GARCH forecasting
# 610 out of 756 in Eigen-GARCH forecasting
# 611 out of 756 in Eigen-GARCH forecasting
# 612 out of 756 in Eigen-GARCH forecasting
# 613 out of 756 in Eigen-GARCH forecasting
# 614 out of 756 in Eigen-GARCH forecasting
# 615 out of 756 in Eigen-GARCH forecasting
# 616 out of 756 in Eigen-GARCH forecasting
# 617 out of 756 in Eigen-GARCH forecasting
# 618 out of 756 in Eigen-GARCH forecasting
# 619 out of 756 in Eigen-GARCH forecasting
# 620 out of 756 in Eigen-GARCH forecasting
# 621 out of 756 in Eigen-GARCH forecasting
# 622 out of 756 in Eigen-GARCH forecasting
# 623 out of 756 in Eigen-GARCH forecasting
# 624 out of 756 in Eigen-GARCH forecasting
# 625 out of 756 in Eigen-GARCH forecasting
# 626 out of 756 in Eigen-GARCH forecasting
# 627 out of 756 in Eigen-GARCH forecasting
# 628 out of 756 in Eigen-GARCH forecasting
# 629 out of 756 in Eigen-GARCH forecasting
# 630 out of 756 in Eigen-GARCH forecasting
# 631 out of 756 in Eigen-GARCH forecasting
# 632 out of 756 in Eigen-GARCH forecasting
# 633 out of 756 in Eigen-GARCH forecasting
# 634 out of 756 in Eigen-GARCH forecasting
# 635 out of 756 in Eigen-GARCH forecasting
# 636 out of 756 in Eigen-GARCH forecasting
# 637 out of 756 in Eigen-GARCH forecasting
# 638 out of 756 in Eigen-GARCH forecasting
# 639 out of 756 in Eigen-GARCH forecasting
# 640 out of 756 in Eigen-GARCH forecasting
# 641 out of 756 in Eigen-GARCH forecasting
# 642 out of 756 in Eigen-GARCH forecasting
# 643 out of 756 in Eigen-GARCH forecasting
# 644 out of 756 in Eigen-GARCH forecasting
# 645 out of 756 in Eigen-GARCH forecasting
# 646 out of 756 in Eigen-GARCH forecasting
# 647 out of 756 in Eigen-GARCH forecasting
# 648 out of 756 in Eigen-GARCH forecasting
# 649 out of 756 in Eigen-GARCH forecasting
# 650 out of 756 in Eigen-GARCH forecasting
# 651 out of 756 in Eigen-GARCH forecasting
# 652 out of 756 in Eigen-GARCH forecasting
# 653 out of 756 in Eigen-GARCH forecasting
# 654 out of 756 in Eigen-GARCH forecasting
# 655 out of 756 in Eigen-GARCH forecasting
# 656 out of 756 in Eigen-GARCH forecasting
# 657 out of 756 in Eigen-GARCH forecasting
# 658 out of 756 in Eigen-GARCH forecasting
# 659 out of 756 in Eigen-GARCH forecasting
# 660 out of 756 in Eigen-GARCH forecasting
# 661 out of 756 in Eigen-GARCH forecasting
# 662 out of 756 in Eigen-GARCH forecasting
# 663 out of 756 in Eigen-GARCH forecasting
# 664 out of 756 in Eigen-GARCH forecasting
# 665 out of 756 in Eigen-GARCH forecasting
# 666 out of 756 in Eigen-GARCH forecasting
# 667 out of 756 in Eigen-GARCH forecasting
# 668 out of 756 in Eigen-GARCH forecasting
# 669 out of 756 in Eigen-GARCH forecasting
# 670 out of 756 in Eigen-GARCH forecasting
# 671 out of 756 in Eigen-GARCH forecasting
# 672 out of 756 in Eigen-GARCH forecasting
# 673 out of 756 in Eigen-GARCH forecasting
# 674 out of 756 in Eigen-GARCH forecasting
# 675 out of 756 in Eigen-GARCH forecasting
# 676 out of 756 in Eigen-GARCH forecasting
# 677 out of 756 in Eigen-GARCH forecasting
# 678 out of 756 in Eigen-GARCH forecasting
# 679 out of 756 in Eigen-GARCH forecasting
# 680 out of 756 in Eigen-GARCH forecasting
# 681 out of 756 in Eigen-GARCH forecasting
# 682 out of 756 in Eigen-GARCH forecasting
# 683 out of 756 in Eigen-GARCH forecasting
# 684 out of 756 in Eigen-GARCH forecasting
# 685 out of 756 in Eigen-GARCH forecasting
# 686 out of 756 in Eigen-GARCH forecasting
# 687 out of 756 in Eigen-GARCH forecasting
# 688 out of 756 in Eigen-GARCH forecasting
# 689 out of 756 in Eigen-GARCH forecasting
# 690 out of 756 in Eigen-GARCH forecasting
# 691 out of 756 in Eigen-GARCH forecasting
# 692 out of 756 in Eigen-GARCH forecasting
# 693 out of 756 in Eigen-GARCH forecasting
# 694 out of 756 in Eigen-GARCH forecasting
# 695 out of 756 in Eigen-GARCH forecasting
# 696 out of 756 in Eigen-GARCH forecasting
# 697 out of 756 in Eigen-GARCH forecasting
# 698 out of 756 in Eigen-GARCH forecasting
# 699 out of 756 in Eigen-GARCH forecasting
# 700 out of 756 in Eigen-GARCH forecasting
# 701 out of 756 in Eigen-GARCH forecasting
# 702 out of 756 in Eigen-GARCH forecasting
# 703 out of 756 in Eigen-GARCH forecasting
# 704 out of 756 in Eigen-GARCH forecasting
# 705 out of 756 in Eigen-GARCH forecasting
# 706 out of 756 in Eigen-GARCH forecasting
# 707 out of 756 in Eigen-GARCH forecasting
# 708 out of 756 in Eigen-GARCH forecasting
# 709 out of 756 in Eigen-GARCH forecasting
# 710 out of 756 in Eigen-GARCH forecasting
# 711 out of 756 in Eigen-GARCH forecasting
# 712 out of 756 in Eigen-GARCH forecasting
# 713 out of 756 in Eigen-GARCH forecasting
# 714 out of 756 in Eigen-GARCH forecasting
# 715 out of 756 in Eigen-GARCH forecasting
# 716 out of 756 in Eigen-GARCH forecasting
# 717 out of 756 in Eigen-GARCH forecasting
# 718 out of 756 in Eigen-GARCH forecasting
# 719 out of 756 in Eigen-GARCH forecasting
# 720 out of 756 in Eigen-GARCH forecasting
# 721 out of 756 in Eigen-GARCH forecasting
# 722 out of 756 in Eigen-GARCH forecasting
# 723 out of 756 in Eigen-GARCH forecasting
# 724 out of 756 in Eigen-GARCH forecasting
# 725 out of 756 in Eigen-GARCH forecasting
# 726 out of 756 in Eigen-GARCH forecasting
# 727 out of 756 in Eigen-GARCH forecasting
# 728 out of 756 in Eigen-GARCH forecasting
# 729 out of 756 in Eigen-GARCH forecasting
# 730 out of 756 in Eigen-GARCH forecasting
# 731 out of 756 in Eigen-GARCH forecasting
# 732 out of 756 in Eigen-GARCH forecasting
# 733 out of 756 in Eigen-GARCH forecasting
# 734 out of 756 in Eigen-GARCH forecasting
# 735 out of 756 in Eigen-GARCH forecasting
# 736 out of 756 in Eigen-GARCH forecasting
# 737 out of 756 in Eigen-GARCH forecasting
# 738 out of 756 in Eigen-GARCH forecasting
# 739 out of 756 in Eigen-GARCH forecasting
# 740 out of 756 in Eigen-GARCH forecasting
# 741 out of 756 in Eigen-GARCH forecasting
# 742 out of 756 in Eigen-GARCH forecasting
# 743 out of 756 in Eigen-GARCH forecasting
# 744 out of 756 in Eigen-GARCH forecasting
# 745 out of 756 in Eigen-GARCH forecasting
# 746 out of 756 in Eigen-GARCH forecasting
# 747 out of 756 in Eigen-GARCH forecasting
# 748 out of 756 in Eigen-GARCH forecasting
# 749 out of 756 in Eigen-GARCH forecasting
# 750 out of 756 in Eigen-GARCH forecasting
# 751 out of 756 in Eigen-GARCH forecasting
# 752 out of 756 in Eigen-GARCH forecasting
# 753 out of 756 in Eigen-GARCH forecasting
# 754 out of 756 in Eigen-GARCH forecasting
# 755 out of 756 in Eigen-GARCH forecasting

# %%
# Make a list for each of the covariance pairs
cov_JPM_MSFT_forcast = []
for t in range(1,N):
    cov_JPM_MSFT_forcast.append(forecastMatrix_eig[t][0][1])

cov_JPM_KO_forcast = []
for t in range(1,N):
    cov_JPM_KO_forcast.append(forecastMatrix_eig[t][0][2])

cov_MSFT_KO_forcast = []
for t in range(1,N):
    cov_MSFT_KO_forcast.append(forecastMatrix_eig[t][1][2])

# %%
# Save results
df = pd.DataFrame(cov_JPM_KO_forcast)
df.to_csv('cov_JPM_KO_forecast_eigen.csv') 

df = pd.DataFrame(cov_JPM_MSFT_forcast )
df.to_csv('cov_JPM_MSFT_forcast_eigen.csv') 

df = pd.DataFrame(cov_MSFT_KO_forcast )
df.to_csv('cov_KO_MSFT_forcast_eigen.csv')

# %%
# save variances
var_BAC_forcast = []
for t in range(1,N):
    var_BAC_forcast.append(forecastMatrix_eig[t][0][0])

var_JPM_forcast = []
for t in range(1,N):
    var_JPM_forcast.append(forecastMatrix_eig[t][1][1])

var_WFC_forcast = []
for t in range(1,N):
    var_WFC_forcast.append(forecastMatrix_eig[t][2][2])

df = pd.DataFrame(var_BAC_forcast)
df.to_csv('var_BAC_forcast_eigen.csv') 

df = pd.DataFrame(var_JPM_forcast)
df.to_csv('var_JPM_forcast_eigen.csv') 

df = pd.DataFrame(var_WFC_forcast)
df.to_csv('var_WFC_forcast.csv')

# %% [markdown]
# ## MVP

# %%
data_simple = np.array(pd.read_csv("returns_R_simple.csv")).T

# %%
weights_eigen = np.zeros((N,1,p))
min_port_ret = np.zeros((N,1))

ell = np.array(([1, 1, 1]))
for n in range(1,N):
    w = np.matmul(np.linalg.inv(forecastMatrix_eig[n]), ell)
    weights_eigen[n,:,:] = w/sum(w)
    min_port_ret[n] = np.sum((np.multiply(weights_eigen[n,:,:], data_simple[:,1505+n])),axis=1)

# %%
df = pd.DataFrame((min_port_ret))
df.to_csv('MVP_eigen.csv')

# %%
mean_min = np.mean(min_port_ret)*np.sqrt(250)
std_min = np.std(min_port_ret)*np.sqrt(250)
sharpe_ratio_min = mean_min/std_min
print(mean_min, std_min, sharpe_ratio_min)
# Out:
# 1.0093139340505437 25.442719336603737 0.03967004944312189

# %% [markdown]
# ## WEEKLY

# %%
# Use the exact same data as in R, for the DCC and GO-GARCH model
data_forecast = data

# %%
# Number of loops in forecast
p = 3
N = 756
# Create parameter containers and covariance matrix container
phi1_eig = np.zeros((N,1))
phi2_eig = np.zeros((N,1))
phi3_eig = np.zeros((N,1))

w1_eig = np.zeros((N,1))
w2_eig = np.zeros((N,1))
w3_eig = np.zeros((N,1))

a11_eig = np.zeros((N,1))
a12_eig = np.zeros((N,1))
a13_eig = np.zeros((N,1))
a21_eig = np.zeros((N,1))
a22_eig = np.zeros((N,1))
a23_eig = np.zeros((N,1))
a31_eig = np.zeros((N,1))
a32_eig = np.zeros((N,1))
a33_eig = np.zeros((N,1))

b11_eig = np.zeros((N,1))
b12_eig = np.zeros((N,1))
b13_eig = np.zeros((N,1))
b21_eig = np.zeros((N,1))
b22_eig = np.zeros((N,1))
b23_eig = np.zeros((N,1))
b31_eig = np.zeros((N,1))
b32_eig = np.zeros((N,1))
b33_eig = np.zeros((N,1))

min_port_ret = np.zeros((N,1))

# %%
for n in range(0,N-1,5):
    # Move estimation window by 5
    X = data_forecast[:,n:1506+n]
    X_f = data_forecast[:,1506+n:1506+n+1]
    print(n, "out of", N, "in Eigen-GARCH forecasting")
    # Generate new lambdas for likelihood estimation
    lambdas_eig = np.tile(np.linalg.eig(np.cov(X.T, rowvar=False))[0], (T,1))
    
    # Use prior estimation results as starting values
    startingVals_eig = list(estimation.x)
    
    # Arguments
    arguments_eig = (np.asarray(X), lambdas_eig)
    
    # Estimation
    estimation = minimize(Eigen_GARCH.eigenLikelihood, x0=startingVals_eig , args=arguments_eig , method="SLSQP", bounds=bnds_eig, options={"maxiter":100000, "ftol":10e-24})
    
    # Save parameters
    phi1_eig[n], phi2_eig[n], phi3_eig[n], w1_eig[n], w2_eig[n], w3_eig[n] , a11_eig[n] , a12_eig[n] , a13_eig[n], a21_eig [n], a22_eig[n], a23_eig[n], a31_eig[n] , a32_eig[n], a33_eig[n] , b11_eig[n] , b12_eig[n], b13_eig[n] , b21_eig[n] , b22_eig[n], b23_eig[n], b31_eig[n] , b32_eig[n], b33_eig[n] = estimation.x
    phi1, phi2, phi3, w1, w2, w3, a11, a12, a13, a21, a22, a23, a31, a32, a33, b11, b12, b13, b21, b22,b23, b31, b32,b33 = estimation.x
 
    W_eig = np.array(([w1, w2, w3]))
    A_eig = np.array(([a11, a12,a13],
                  [a21, a22,a23],
                  [a31, a32,a33]))
    B_eig = np.array(([b11, b12,b13],
                  [b21, b22,b23],
                  [b31, b32,b33]))
    V_eig = np.array(([np.cos(phi1), np.sin(phi1),0],[-np.sin(phi1), np.cos(phi1),0 ], [0, 0,1 ])
                    )@ np.array(([np.cos(phi2), 0, np.sin(phi2)], [0, 1,0 ], [-np.sin(phi2), 0, np.cos(phi2)])
                           )@ np.array(( [1, 0,0 ], [0,np.cos(phi3), np.sin(phi3)], [0,-np.sin(phi3), np.cos(phi3)]))
    
    Xtilde = V_eig.transpose() @ X
    T = 1506
    lambdas = (np.ones((k,T))).transpose()
    
    condVar_eig = np.zeros((T,k,k))
    
    for t in range(1,T):
        lambdas[t] = W_eig+np.concatenate(A_eig @ np.multiply(Xtilde[:,t-1:t],Xtilde[:,t-1:t]), axis=0 )+ B_eig @ lambdas[t-1]
        condVar_eig[t] = V_eig @ np.diag(lambdas[t]) @ V_eig.T
     
    Xtilde_f = V_eig.transpose() @ X_f
    
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas[T-1]
 
    # Conditional eigenvalue at time t+1
    #Xtilde = V_eig.transpose() @ X
    
    # Store 1-step forecast
    #forecastMatrix_eig[n,:,:] = condVar_eig[T-1]
    #1
    forecastMatrix_eig_1 = V_eig @ np.diag(lambdas_f) @ V_eig.T
    
    #2
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas_f
    forecastMatrix_eig_2 = V_eig @ np.diag(lambdas_f) @ V_eig.T
    
    #3
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas_f
    forecastMatrix_eig_3 = V_eig @ np.diag(lambdas_f) @ V_eig.T
    
    #4
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas_f
    forecastMatrix_eig_4 = V_eig @ np.diag(lambdas_f) @ V_eig.T
    
    #5
    lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas_f
    forecastMatrix_eig_5 = V_eig @ np.diag(lambdas_f) @ V_eig.T
    
    # Total
    forecastMatrix_eig_weekly = forecastMatrix_eig_1 +forecastMatrix_eig_2+forecastMatrix_eig_3+forecastMatrix_eig_4+forecastMatrix_eig_5
    
    #MVP
    ell = np.array(([1, 1, 1]))

    w = np.matmul(np.linalg.inv(forecastMatrix_eig_weekly), ell)
    w_weekly = w/sum(w)
    min_port_ret[n+1] = np.sum((np.multiply(w_weekly, data_simple[:,1506+n].T)))
    min_port_ret[n+2] = np.sum((np.multiply(w_weekly, data_simple[:,1506+n+1].T)))
    min_port_ret[n+3] = np.sum((np.multiply(w_weekly, data_simple[:,1506+n+2].T)))
    min_port_ret[n+4] = np.sum((np.multiply(w_weekly, data_simple[:,1506+n+3].T)))
    min_port_ret[n+5] = np.sum((np.multiply(w_weekly, data_simple[:,1506+n+4].T)))
# Out:
# 0 out of 756 in Eigen-GARCH forecasting
# 5 out of 756 in Eigen-GARCH forecasting
# 10 out of 756 in Eigen-GARCH forecasting
# 15 out of 756 in Eigen-GARCH forecasting
# 20 out of 756 in Eigen-GARCH forecasting
# 25 out of 756 in Eigen-GARCH forecasting
# 30 out of 756 in Eigen-GARCH forecasting
# 35 out of 756 in Eigen-GARCH forecasting
# 40 out of 756 in Eigen-GARCH forecasting
# 45 out of 756 in Eigen-GARCH forecasting
# 50 out of 756 in Eigen-GARCH forecasting
# 55 out of 756 in Eigen-GARCH forecasting
# 60 out of 756 in Eigen-GARCH forecasting
# 65 out of 756 in Eigen-GARCH forecasting
# 70 out of 756 in Eigen-GARCH forecasting
# 75 out of 756 in Eigen-GARCH forecasting
# 80 out of 756 in Eigen-GARCH forecasting
# 85 out of 756 in Eigen-GARCH forecasting
# 90 out of 756 in Eigen-GARCH forecasting
# 95 out of 756 in Eigen-GARCH forecasting
# 100 out of 756 in Eigen-GARCH forecasting
# 105 out of 756 in Eigen-GARCH forecasting
# 110 out of 756 in Eigen-GARCH forecasting
# 115 out of 756 in Eigen-GARCH forecasting
# 120 out of 756 in Eigen-GARCH forecasting
# 125 out of 756 in Eigen-GARCH forecasting
# 130 out of 756 in Eigen-GARCH forecasting
# 135 out of 756 in Eigen-GARCH forecasting
# 140 out of 756 in Eigen-GARCH forecasting
# 145 out of 756 in Eigen-GARCH forecasting
# 150 out of 756 in Eigen-GARCH forecasting
# 155 out of 756 in Eigen-GARCH forecasting
# 160 out of 756 in Eigen-GARCH forecasting
# 165 out of 756 in Eigen-GARCH forecasting
# 170 out of 756 in Eigen-GARCH forecasting
# 175 out of 756 in Eigen-GARCH forecasting
# 180 out of 756 in Eigen-GARCH forecasting
# 185 out of 756 in Eigen-GARCH forecasting
# 190 out of 756 in Eigen-GARCH forecasting
# 195 out of 756 in Eigen-GARCH forecasting
# 200 out of 756 in Eigen-GARCH forecasting
# 205 out of 756 in Eigen-GARCH forecasting
# 210 out of 756 in Eigen-GARCH forecasting
# 215 out of 756 in Eigen-GARCH forecasting
# 220 out of 756 in Eigen-GARCH forecasting
# 225 out of 756 in Eigen-GARCH forecasting
# 230 out of 756 in Eigen-GARCH forecasting
# 235 out of 756 in Eigen-GARCH forecasting
# 240 out of 756 in Eigen-GARCH forecasting
# 245 out of 756 in Eigen-GARCH forecasting
# 250 out of 756 in Eigen-GARCH forecasting
# 255 out of 756 in Eigen-GARCH forecasting
# 260 out of 756 in Eigen-GARCH forecasting
# 265 out of 756 in Eigen-GARCH forecasting
# 270 out of 756 in Eigen-GARCH forecasting
# 275 out of 756 in Eigen-GARCH forecasting
# 280 out of 756 in Eigen-GARCH forecasting
# 285 out of 756 in Eigen-GARCH forecasting
# 290 out of 756 in Eigen-GARCH forecasting
# 295 out of 756 in Eigen-GARCH forecasting
# 300 out of 756 in Eigen-GARCH forecasting
# 305 out of 756 in Eigen-GARCH forecasting
# 310 out of 756 in Eigen-GARCH forecasting
# 315 out of 756 in Eigen-GARCH forecasting
# 320 out of 756 in Eigen-GARCH forecasting
# 325 out of 756 in Eigen-GARCH forecasting
# 330 out of 756 in Eigen-GARCH forecasting
# 335 out of 756 in Eigen-GARCH forecasting
# 340 out of 756 in Eigen-GARCH forecasting
# 345 out of 756 in Eigen-GARCH forecasting
# 350 out of 756 in Eigen-GARCH forecasting
# 355 out of 756 in Eigen-GARCH forecasting
# 360 out of 756 in Eigen-GARCH forecasting
# 365 out of 756 in Eigen-GARCH forecasting
# 370 out of 756 in Eigen-GARCH forecasting
# 375 out of 756 in Eigen-GARCH forecasting
# 380 out of 756 in Eigen-GARCH forecasting
# 385 out of 756 in Eigen-GARCH forecasting
# 390 out of 756 in Eigen-GARCH forecasting
# 395 out of 756 in Eigen-GARCH forecasting
# 400 out of 756 in Eigen-GARCH forecasting
# 405 out of 756 in Eigen-GARCH forecasting
# 410 out of 756 in Eigen-GARCH forecasting
# 415 out of 756 in Eigen-GARCH forecasting
# 420 out of 756 in Eigen-GARCH forecasting
# 425 out of 756 in Eigen-GARCH forecasting
# 430 out of 756 in Eigen-GARCH forecasting
# 435 out of 756 in Eigen-GARCH forecasting
# 440 out of 756 in Eigen-GARCH forecasting
# 445 out of 756 in Eigen-GARCH forecasting
# 450 out of 756 in Eigen-GARCH forecasting
# 455 out of 756 in Eigen-GARCH forecasting
# 460 out of 756 in Eigen-GARCH forecasting
# 465 out of 756 in Eigen-GARCH forecasting
# 470 out of 756 in Eigen-GARCH forecasting
# 475 out of 756 in Eigen-GARCH forecasting
# 480 out of 756 in Eigen-GARCH forecasting
# 485 out of 756 in Eigen-GARCH forecasting
# 490 out of 756 in Eigen-GARCH forecasting
# 495 out of 756 in Eigen-GARCH forecasting
# 500 out of 756 in Eigen-GARCH forecasting
# 505 out of 756 in Eigen-GARCH forecasting
# 510 out of 756 in Eigen-GARCH forecasting
# 515 out of 756 in Eigen-GARCH forecasting
# 520 out of 756 in Eigen-GARCH forecasting
# 525 out of 756 in Eigen-GARCH forecasting
# 530 out of 756 in Eigen-GARCH forecasting
# 535 out of 756 in Eigen-GARCH forecasting
# 540 out of 756 in Eigen-GARCH forecasting
# 545 out of 756 in Eigen-GARCH forecasting
# 550 out of 756 in Eigen-GARCH forecasting
# 555 out of 756 in Eigen-GARCH forecasting
# 560 out of 756 in Eigen-GARCH forecasting
# 565 out of 756 in Eigen-GARCH forecasting
# 570 out of 756 in Eigen-GARCH forecasting
# 575 out of 756 in Eigen-GARCH forecasting
# 580 out of 756 in Eigen-GARCH forecasting
# 585 out of 756 in Eigen-GARCH forecasting
# 590 out of 756 in Eigen-GARCH forecasting
# 595 out of 756 in Eigen-GARCH forecasting
# 600 out of 756 in Eigen-GARCH forecasting
# 605 out of 756 in Eigen-GARCH forecasting
# 610 out of 756 in Eigen-GARCH forecasting
# 615 out of 756 in Eigen-GARCH forecasting
# 620 out of 756 in Eigen-GARCH forecasting
# 625 out of 756 in Eigen-GARCH forecasting
# 630 out of 756 in Eigen-GARCH forecasting
# 635 out of 756 in Eigen-GARCH forecasting
# 640 out of 756 in Eigen-GARCH forecasting
# 645 out of 756 in Eigen-GARCH forecasting
# 650 out of 756 in Eigen-GARCH forecasting
# 655 out of 756 in Eigen-GARCH forecasting
# 660 out of 756 in Eigen-GARCH forecasting
# 665 out of 756 in Eigen-GARCH forecasting
# 670 out of 756 in Eigen-GARCH forecasting
# 675 out of 756 in Eigen-GARCH forecasting
# 680 out of 756 in Eigen-GARCH forecasting
# 685 out of 756 in Eigen-GARCH forecasting
# 690 out of 756 in Eigen-GARCH forecasting
# 695 out of 756 in Eigen-GARCH forecasting
# 700 out of 756 in Eigen-GARCH forecasting
# 705 out of 756 in Eigen-GARCH forecasting
# 710 out of 756 in Eigen-GARCH forecasting
# 715 out of 756 in Eigen-GARCH forecasting
# 720 out of 756 in Eigen-GARCH forecasting
# 725 out of 756 in Eigen-GARCH forecasting
# 730 out of 756 in Eigen-GARCH forecasting
# 735 out of 756 in Eigen-GARCH forecasting
# 740 out of 756 in Eigen-GARCH forecasting
# 745 out of 756 in Eigen-GARCH forecasting
# 750 out of 756 in Eigen-GARCH forecasting
# 755 out of 756 in Eigen-GARCH forecasting
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hn/7trmh8cs68vbgx39w4d663b40000gn/T/ipykernel_50891/3399256059.py in <module>
#      43     Xtilde_f = V_eig.transpose() @ X_f
#      44
# ---> 45     lambdas_f = W_eig + np.concatenate(A_eig @ np.multiply(Xtilde_f,Xtilde_f), axis=0 )+ B_eig @ lambdas[T-1]
#      46
#      47     # Conditional eigenvalue at time t+1
#
# ValueError: operands could not be broadcast together with shapes (3,) (0,)

# %%
df = pd.DataFrame((min_port_ret))
df.to_csv('MVP_eigen_week.csv')

# %%
mean_min = np.mean(min_port_ret)*np.sqrt(250)
std_min = np.std(min_port_ret)*np.sqrt(250)
sharpe_ratio_min = mean_min/std_min
print(mean_min, std_min, sharpe_ratio_min)
# Out:
# 0.5632753946828599 26.083702147846836 0.02159491745037264
